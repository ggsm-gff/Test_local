# %%
import datetime as dt

# %%
now_dt = dt.datetime.now()
today_dt = dt.date.today()

print(type(now_dt))
print(type(today_dt))
# Out:
# <class 'datetime.datetime'>
# <class 'datetime.date'>

# %%
#now_dt.strftime('%Y-%m-%d')
#today_dt.strftime('%Y/%m/%d')

#Calcular el fin de mes de la fecha actual y tambien el fin de mes del mes anterior
m0_dt = now_dt.replace(day=1).date() + dateutil.relativedelta.relativedelta(days=-1)
m1_dt = now_dt.replace(day=1).date() + dateutil.relativedelta.relativedelta(months=1,days=-1)

print(f'm0_dt: {m0_dt}')
print(f'm1_dt: {m1_dt}')
# Out:
# m0_dt: 2026-03-31
# m1_dt: 2026-04-30

# %%
#now_dt.time
#now_dt + dt.timedelta(days=-24)
now_dt.time()
days_to_remove = now_dt.day
# Out:
# datetime.time(9, 30, 52, 32035)

# %%
m0_dt = now_dt.date() + dt.timedelta(days = - now_dt.day)
m0_dt
# Out:
# datetime.date(2026, 3, 31)

# %%
#now_dt.month + 2

#now_dt.replace(day=1, month=2)
# Out:
# datetime.datetime(2026, 2, 1, 9, 30, 52, 32035)

# %%
import dateutil

now_dt + dateutil.relativedelta(month=2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 3
#       1 import dateutil
# ----> 3 now_dt + dateutil.relativedelta(month=2)
#
# TypeError: 'module' object is not callable

# %%
now_dt.date() + dateutil.relativedelta.relativedelta(months=2, day=1) + dt.timedelta(days=-1)
# Out:
# datetime.date(2026, 5, 31)

# %%
import logging

logging.basicConfig(
    #filename=f'{file_name}.log',
    filemode='a',
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    force=True
)

logging.log(level=logging.INFO, msg='prueba')
# Out:
# 2026-04-24 11:15:17 - INFO - prueba

# %%
import logging
logging.basicConfig(
    filemode='a', 
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%d %H:%M:%S',
    force=True
    )

# %%
help(logging.basicConfig)
# Out:
# Help on function basicConfig in module logging:
#
# basicConfig(**kwargs)
#     Do basic configuration for the logging system.
#
#     This function does nothing if the root logger already has handlers
#     configured, unless the keyword argument *force* is set to ``True``.
#     It is a convenience method intended for use by simple scripts
#     to do one-shot configuration of the logging package.
#
#     The default behaviour is to create a StreamHandler which writes to
#     sys.stderr, set a formatter using the BASIC_FORMAT format string, and
#     add the handler to the root logger.
#
#     A number of optional keyword arguments may be specified, which can alter
#     the default behaviour.
#
#     filename  Specifies that a FileHandler be created, using the specified
#               filename, rather than a StreamHandler.
#     filemode  Specifies the mode to open the file, if filename is specified
#               (if filemode is unspecified, it defaults to 'a').
# ...

# %%
logging.ERROR
# Out:
# 40

# %%
logging.warning(msg='prueba')
# Out:
# 2026-05-04 12:37:21 - WARNING - prueba

# %%
dir(logging)
# Out:
# ['BASIC_FORMAT',
#  'BufferingFormatter',
#  'CRITICAL',
#  'DEBUG',
#  'ERROR',
#  'FATAL',
#  'FileHandler',
#  'Filter',
#  'Filterer',
#  'Formatter',
#  'GenericAlias',
#  'Handler',
#  'INFO',
#  'LogRecord',
#  'Logger',
#  'LoggerAdapter',
#  'Manager',
#  'NOTSET',
#  'NullHandler',
#  'PercentStyle',
#  'PlaceHolder',
#  'RootLogger',
#  'StrFormatStyle',
#  'StreamHandler',
#  'StringTemplateStyle',
#  'Template',
#  'WARN',
#  'WARNING',
#  '_STYLES',
#  '_StderrHandler',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__date__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__status__',
#  '__version__',
#  '_acquireLock',
#  '_addHandlerRef',
#  '_checkLevel',
#  '_defaultFormatter',
#  '_defaultLastResort',
#  '_handlerList',
#  '_handlers',
#  '_is_internal_frame',
#  '_levelToName',
#  '_lock',
#  '_logRecordFactory',
#  '_loggerClass',
#  '_nameToLevel',
# ...

# %%
import os

os.listdir()
# Out:
# ['.vscode', 'builtin', 'example.db', 'Notebook 1.ipynb', 'Nueva_Base.sqlite']

# %%
dir(logging.basicConfig)
# Out:
# ['__annotations__',
#  '__builtins__',
#  '__call__',
#  '__class__',
#  '__closure__',
#  '__code__',
#  '__defaults__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__get__',
#  '__getattribute__',
#  '__getstate__',
#  '__globals__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__kwdefaults__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__name__',
#  '__ne__',
#  '__new__',
#  '__qualname__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__type_params__']
