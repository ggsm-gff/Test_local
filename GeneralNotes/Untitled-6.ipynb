# %%
src_file_path = 'C:\\Users\\HN34064\\Desktop\\PPR\\Dev\\Data\\Log-Train.csv'

with open(src_file_path, 'r') as file:
    data = file.re

# %%
file = open ('C:\\Users\\HN34064\\Desktop\\PPR\\Dev\\Data\\Log-Train.csv',mode='r')

# %%
tmp = file.read()

# %%
dir(file)
# Out:
# ['_CHUNK_SIZE',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  '_finalizing',
#  'buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'line_buffering',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'write_through',
#  'writelines']

# %%
dir(file.buffer)
# Out:
# ['__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  '_dealloc_warn',
#  '_finalizing',
#  'close',
#  'closed',
#  'detach',
#  'fileno',
#  'flush',
#  'isatty',
#  'mode',
#  'name',
#  'peek',
#  'raw',
#  'read',
#  'read1',
#  'readable',
#  'readinto',
#  'readinto1',
#  'readline',
#  'readlines',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'writelines']

# %%
file.seek(0)
# Out:
# 0

# %%
file.tell()
# Out:
# 0

# %%
file.readline()
# Out:
# 'FECHA,IMAE_VARIACION_INTERANUAL,IMAE_VARIACION_INTERANUAL_TC,M2%PIB,PIB_VAR_MN,TASA_PASIVO_PONDERADO_POR_SALDOS_MN,CC%PIB,M1%PIB,121_INVERSIONES_FINANCIERAS_A_COSTO_AMORTIZADO\n'

# %%
file.readlines()
# Out:
# ['FECHA,IMAE_VARIACION_INTERANUAL,IMAE_VARIACION_INTERANUAL_TC,M2%PIB,PIB_VAR_MN,TASA_PASIVO_PONDERADO_POR_SALDOS_MN,CC%PIB,M1%PIB,121_INVERSIONES_FINANCIERAS_A_COSTO_AMORTIZADO\n',
#  '2018-04-30,2.99,0.020000000000000018,-0.006157194198492588,-0.0539844236767073,-0.08999999999999897,9.317898025924115e-05,-0.003163223670410109,22.973939893908767\n',
#  '2018-05-31,1.36,0.09999999999999964,0.014603193728005115,-0.04936534911577674,0.0799999999999983,8.402851218265034e-05,0.001839425784257498,22.979347734543342\n',
#  '2018-06-30,4.17,0.07000000000000028,-0.07007999091759953,-0.0041912317226237145,-0.03999999999999915,0.021320314022247544,-0.00357303235186035,23.108686769196243\n',
#  '2018-07-31,4.15,-0.050000000000000266,0.010281952025697372,0.04529408053314142,-0.14999999999999947,0.0006992108964222477,0.002540187907235869,23.143521330291946\n',
# ...

# %%
print(tmp)
# Out:
# FECHA,IMAE_VARIACION_INTERANUAL,IMAE_VARIACION_INTERANUAL_TC,M2%PIB,PIB_VAR_MN,TASA_PASIVO_PONDERADO_POR_SALDOS_MN,CC%PIB,M1%PIB,121_INVERSIONES_FINANCIERAS_A_COSTO_AMORTIZADO
# 2018-04-30,2.99,0.020000000000000018,-0.006157194198492588,-0.0539844236767073,-0.08999999999999897,9.317898025924115e-05,-0.003163223670410109,22.973939893908767
# 2018-05-31,1.36,0.09999999999999964,0.014603193728005115,-0.04936534911577674,0.0799999999999983,8.402851218265034e-05,0.001839425784257498,22.979347734543342
# 2018-06-30,4.17,0.07000000000000028,-0.07007999091759953,-0.0041912317226237145,-0.03999999999999915,0.021320314022247544,-0.00357303235186035,23.108686769196243
# 2018-07-31,4.15,-0.050000000000000266,0.010281952025697372,0.04529408053314142,-0.14999999999999947,0.0006992108964222477,0.002540187907235869,23.143521330291946
# 2018-08-31,3.6,-0.13999999999999968,0.05291653915111638,0.046035735783549685,0.2699999999999996,0.0007363023263569288,0.038379843494444066,23.05525878424819
# ...

# %%
config_path = 'C:\\Users\\HN34064\\Desktop\\PPR\\Dev\\src\\config.json'
new_file_path = 'C:\\Users\\HN34064\\Desktop\\PPR\\Dev\\Data\\env.conf'

with open(config_path, 'r',encoding='utf-8') as file:
    datos = file.read()

print(datos)
# Out:
# {
# "andromeda" :
#     "DRIVER={ODBC Driver 17 for SQL Server};    SERVER=andromeda;    DATABASE=MIS_RIESGOS;    Trusted_Connection=yes;"
# }

# %%
print(type(datos))
# Out:
# <class 'str'>

# %%
with open(new_file_path,'a',encoding='utf-8') as file:
    file.write(datos)
