# %%
from itertools import combinations
from collections import Counter

pokemon_types = ['Bug',
 'Dark',
 'Dragon',
 'Electric',
 'Fairy',
 'Fighting',
 'Fire',
 'Flying',
 'Ghost',
 'Grass',
 'Ground',
 'Ice',
 'Normal',
 'Poison',
 'Psychic',
 'Rock',
 'Steel',
 'Water']

possible_pairs = [*combinations(pokemon_types, 2)]

# Create an empty list called enumerated_tuples
enumerated_tuples = []

for i,pair in enumerate(possible_pairs, 1):
    enumerated_pair_tuple = (i,) + pair
    enumerated_tuples.append(enumerated_pair_tuple)
print(enumerated_pair_tuple)

# Convert all tuples in enumerated_tuples to a list
#enumerated_pairs = [*map(list, enumerated_tuples)]
#print(enumerated_pairs)
# Out:
# (153, 'Steel', 'Water')

# %%
possible_pairs
# Out:
# [('Bug', 'Dark'),
#  ('Bug', 'Dragon'),
#  ('Bug', 'Electric'),
#  ('Bug', 'Fairy'),
#  ('Bug', 'Fighting'),
#  ('Bug', 'Fire'),
#  ('Bug', 'Flying'),
#  ('Bug', 'Ghost'),
#  ('Bug', 'Grass'),
#  ('Bug', 'Ground'),
#  ('Bug', 'Ice'),
#  ('Bug', 'Normal'),
#  ('Bug', 'Poison'),
#  ('Bug', 'Psychic'),
#  ('Bug', 'Rock'),
#  ('Bug', 'Steel'),
#  ('Bug', 'Water'),
#  ('Dark', 'Dragon'),
#  ('Dark', 'Electric'),
#  ('Dark', 'Fairy'),
#  ('Dark', 'Fighting'),
#  ('Dark', 'Fire'),
#  ('Dark', 'Flying'),
#  ('Dark', 'Ghost'),
#  ('Dark', 'Grass'),
#  ('Dark', 'Ground'),
#  ('Dark', 'Ice'),
#  ('Dark', 'Normal'),
#  ('Dark', 'Poison'),
#  ('Dark', 'Psychic'),
#  ('Dark', 'Rock'),
#  ('Dark', 'Steel'),
#  ('Dark', 'Water'),
#  ('Dragon', 'Electric'),
#  ('Dragon', 'Fairy'),
#  ('Dragon', 'Fighting'),
#  ('Dragon', 'Fire'),
#  ('Dragon', 'Flying'),
#  ('Dragon', 'Ghost'),
#  ('Dragon', 'Grass'),
#  ('Dragon', 'Ground'),
#  ('Dragon', 'Ice'),
#  ('Dragon', 'Normal'),
#  ('Dragon', 'Poison'),
# ...

# %%
var = (i,) + (23,)
print(var)
print(type(var))
# Out:
# (153, 23)
# <class 'tuple'>

# %%
from itertools import combinations

pokemon_types = ['Bug',
 'Dark',
 'Dragon',
 'Electric',
 'Fairy',
 'Fighting',
 'Fire',
 'Flying',
 'Ghost',
 'Grass',
 'Ground',
 'Ice',
 'Normal',
 'Poison',
 'Psychic',
 'Rock',
 'Steel',
 'Water']

print(*combinations(pokemon_types,3))
# Out:
# ('Bug', 'Dark', 'Dragon') ('Bug', 'Dark', 'Electric') ('Bug', 'Dark', 'Fairy') ('Bug', 'Dark', 'Fighting') ('Bug', 'Dark', 'Fire') ('Bug', 'Dark', 'Flying') ('Bug', 'Dark', 'Ghost') ('Bug', 'Dark', 'Grass') ('Bug', 'Dark', 'Ground') ('Bug', 'Dark', 'Ice') ('Bug', 'Dark', 'Normal') ('Bug', 'Dark', 'Poison') ('Bug', 'Dark', 'Psychic') ('Bug', 'Dark', 'Rock') ('Bug', 'Dark', 'Steel') ('Bug', 'Dark', 'Water') ('Bug', 'Dragon', 'Electric') ('Bug', 'Dragon', 'Fairy') ('Bug', 'Dragon', 'Fighting') ('Bug', 'Dragon', 'Fire') ('Bug', 'Dragon', 'Flying') ('Bug', 'Dragon', 'Ghost') ('Bug', 'Dragon', 'Grass') ('Bug', 'Dragon', 'Ground') ('Bug', 'Dragon', 'Ice') ('Bug', 'Dragon', 'Normal') ('Bug', 'Dragon', 'Poison') ('Bug', 'Dragon', 'Psychic') ('Bug', 'Dragon', 'Rock') ('Bug', 'Dragon', 'Steel') ('Bug', 'Dragon', 'Water') ('Bug', 'Electric', 'Fairy') ('Bug', 'Electric', 'Fighting') ('Bug', 'Electric', 'Fire') ('Bug', 'Electric', 'Flying') ('Bug', 'Electric', 'Ghost') ('Bug', 'Electric', 'Grass')
# ...

# %%
import os

print(os.environ.keys())
# Out:
# KeysView(environ({'ALLUSERSPROFILE': 'C:\\ProgramData', 'APPDATA': 'C:\\Users\\HN34064\\AppData\\Roaming', 'APPLICATION_INSIGHTS_NO_STATSBEAT': 'true', 'BPPDOMAIN_MANAGER_ASM': 'EdrDotNet, Version+168.0.0.0, Culture+neutral, PublicKeyToken+da1b3922653ea916', 'BPPDOMAIN_MANAGER_TYPE': 'EdrDotNet.EdrAppDomainManager', 'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\crashpad_19792_AHHHZIBDWEUYLBJW', 'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files', 'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files', 'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files', 'COMPUTERNAME': 'HNBNL103034064', 'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe', 'COPILOT_OTEL_ENABLED': 'true', 'COPILOT_OTEL_EXPORTER_TYPE': 'file', 'COPILOT_OTEL_FILE_EXPORTER_PATH': '\\\\.\\nul', 'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData', 'EFC_4496_1262719628': '1', 'EFC_4496_1592913036': '1', 'EFC_4496_2283032206': '1', 'EFC_4496_2775293581': '1', 'EFC_4496_3789132940': '1', 'ELECTRON_RUN_AS_NODE':
# ...

# %%
for key in os.environ.keys():
    print(key)
# Out:
# ALLUSERSPROFILE
# APPDATA
# APPLICATION_INSIGHTS_NO_STATSBEAT
# BPPDOMAIN_MANAGER_ASM
# BPPDOMAIN_MANAGER_TYPE
# CHROME_CRASHPAD_PIPE_NAME
# COMMONPROGRAMFILES
# COMMONPROGRAMFILES(X86)
# COMMONPROGRAMW6432
# COMPUTERNAME
# COMSPEC
# COPILOT_OTEL_ENABLED
# COPILOT_OTEL_EXPORTER_TYPE
# COPILOT_OTEL_FILE_EXPORTER_PATH
# DRIVERDATA
# EFC_4496_1262719628
# EFC_4496_1592913036
# EFC_4496_2283032206
# EFC_4496_2775293581
# EFC_4496_3789132940
# ELECTRON_RUN_AS_NODE
# FPS_BROWSER_APP_PROFILE_STRING
# FPS_BROWSER_USER_PROFILE_STRING
# HOMEDRIVE
# HOMEPATH
# JAVA_HOME
# JPY_INTERRUPT_EVENT
# LOCALAPPDATA
# LOGONSERVER
# MY_VAR
# NUMBER_OF_PROCESSORS
# ONEDRIVE
# OS
# OTEL_INSTRUMENTATION_GENAI_CAPTURE_MESSAGE_CONTENT
# PATH
# PATHEXT
# PROCESSOR_ARCHITECTURE
# PROCESSOR_IDENTIFIER
# PROCESSOR_LEVEL
# PROCESSOR_REVISION
# PROGRAMDATA
# PROGRAMFILES
# PROGRAMFILES(X86)
# PROGRAMW6432
# PSMODULEPATH
# PUBLIC
# PYDEVD_IPYTHON_COMPATIBLE_DEBUGGING
# PYTHONIOENCODING
# PYTHONUNBUFFERED
# ...

# %%
import pandas as pd

path = 'c:/Users/HN34064/Downloads/DevSec/heroes.parquet'
df = pd.read_parquet(path)
df.head()
# Out:
#           Nombre  height  wieght                   datetime
# 0         A-Bomb   203.0   203.0 2026-05-05 11:43:58.616529
# 1     Abe Sapien   191.0   191.0 2026-05-05 11:43:58.616529
# 2       Abin Sur   185.0   185.0 2026-05-05 11:43:58.616529
# 3    Abomination   203.0   203.0 2026-05-05 11:43:58.616529
# 4  Absorbing Man   193.0   193.0 2026-05-05 11:43:58.616529

# %%
df['datetime'].dt.date
# Out:
# 0      2026-05-05
# 1      2026-05-05
# 2      2026-05-05
# 3      2026-05-05
# 4      2026-05-05
#           ...
# 475    2026-05-05
# 476    2026-05-05
# 477    2026-05-05
# 478    2026-05-05
# 479    2026-05-05
# Name: datetime, Length: 480, dtype: object

# %%
import os
os.makedirs('c:/Users/HN34064/Desktop/Dev/Temp/PRJ/src', exist_ok=True)
os.makedirs('c:/Users/HN34064/Desktop/Dev/Temp/PRJ/data',exist_ok=True)
os.makedirs('c:/Users/HN34064/Desktop/Dev/Temp/PRJ/logs', exist_ok=True)

# %%
import logging

logging.basicConfig(
    format='%(asctime)s - %(levelname)s - %(message)s',
    datefmt='%Y-%m-%D %H:%M:%S',
    force=True,
    filemode='a',
    filename='../logs/ahorita.log',
    level=logging.INFO
    )

# %%
logging.error(msg='hay clavo')
